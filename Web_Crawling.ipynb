# %% [markdown]
# <a href="https://colab.research.google.com/github/rizaldiff/tugas1_BigData_Crawling/blob/main/Web_Crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.4/286.4 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 21.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 9.5 MB/s eta 0:00:00
# ...

# %%
# !scrapy startproject scrap_project
# Out:
# New Scrapy project 'scrap_project', using template directory '/usr/local/lib/python3.10/dist-packages/scrapy/templates/project', created in:
#     /content/scrap_project
#
# You can start your first spider with:
#     cd scrap_project
#     scrapy genspider example example.com

# %%
# %cd /content/scrap_project
# Out:
# /content/scrap_project

# %%
# !scrapy crawl cnn -o cnn.json
# Out:
# 2023-10-13 03:15:00 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrap_project)
# 2023-10-13 03:15:00 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0], pyOpenSSL 23.2.0 (OpenSSL 3.1.3 19 Sep 2023), cryptography 41.0.4, Platform Linux-5.15.120+-x86_64-with-glibc2.35
# 2023-10-13 03:15:00 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-10-13 03:15:00 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-10-13 03:15:00 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-10-13 03:15:00 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2023-10-13 03:15:00 [scrapy.extensions.telnet] INFO: Telnet Password: 861532b6724ac77f
# 2023-10-13 03:15:00 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
# !scrapy crawl kompas -o kompas.json
# Out:
# 2023-10-13 02:55:40 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrap_project)
# 2023-10-13 02:55:40 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0], pyOpenSSL 23.2.0 (OpenSSL 3.1.3 19 Sep 2023), cryptography 41.0.4, Platform Linux-5.15.120+-x86_64-with-glibc2.35
# 2023-10-13 02:55:40 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-10-13 02:55:40 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-10-13 02:55:40 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-10-13 02:55:40 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2023-10-13 02:55:40 [scrapy.extensions.telnet] INFO: Telnet Password: 8aa2128828327685
# 2023-10-13 02:55:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...
